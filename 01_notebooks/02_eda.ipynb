# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df= pd.read_csv('../02_data/DP_LIVE_14122018082747325.csv')

# %%
df.head()
# Out:
#   LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS       EMP     TOT  PC_WKGPOP         A  1987  65.30288        NaN
# 1      AUS       EMP     TOT  PC_WKGPOP         A  1988  66.48173        NaN
# 2      AUS       EMP     TOT  PC_WKGPOP         A  1989  68.19857        NaN
# 3      AUS       EMP     TOT  PC_WKGPOP         A  1990  68.37136        NaN
# 4      AUS       EMP     TOT  PC_WKGPOP         A  1991  65.92150        NaN

# %%
df.columns = map(str.lower, df.columns)

# %%
df[df['location']=='USA']
# Out:
#     location indicator subject    measure frequency  time     value flag codes
# 522      USA       EMP     TOT  PC_WKGPOP         A  1987  70.74065        NaN
# 523      USA       EMP     TOT  PC_WKGPOP         A  1988  71.64634        NaN
# 524      USA       EMP     TOT  PC_WKGPOP         A  1989  72.49520        NaN
# 525      USA       EMP     TOT  PC_WKGPOP         A  1990  72.19167        NaN
# 526      USA       EMP     TOT  PC_WKGPOP         A  1991  70.96761        NaN
# 527      USA       EMP     TOT  PC_WKGPOP         A  1992  70.80585        NaN
# 528      USA       EMP     TOT  PC_WKGPOP         A  1993  71.20782        NaN
# 529      USA       EMP     TOT  PC_WKGPOP         A  1994  72.00175        NaN
# 530      USA       EMP     TOT  PC_WKGPOP         A  1995  72.53490        NaN
# 531      USA       EMP     TOT  PC_WKGPOP         A  1996  72.85875        NaN
# 532      USA       EMP     TOT  PC_WKGPOP         A  1997  73.50204        NaN
# ...

# %%
df.location.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'SVN', 'ZAF', 'EU28',
#        'OECD', 'G-7', 'EA19', 'COL', 'LVA', 'LTU'], dtype=object)

# %%
sns.lineplot(x='time',y='value',data=df)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.time.unique()
# Out:
# array([1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
df.columns
# Out:
# Index(['location', 'indicator', 'subject', 'measure', 'frequency', 'time',
#        'value', 'flag codes'],
#       dtype='object')

# %%
df.location.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'CHL', 'EST', 'ISR', 'SVN', 'ZAF', 'EU28',
#        'OECD', 'G-7', 'EA19', 'COL', 'LVA', 'LTU'], dtype=object)

# %%
df['location']
# Out:
# 0      AUS
# 1      AUS
# 2      AUS
# 3      AUS
# 4      AUS
# 5      AUS
# 6      AUS
# 7      AUS
# 8      AUS
# 9      AUS
# 10     AUS
# 11     AUS
# 12     AUS
# 13     AUS
# 14     AUS
# 15     AUS
# 16     AUS
# 17     AUS
# 18     AUS
# 19     AUS
# 20     AUS
# 21     AUS
# 22     AUS
# 23     AUS
# 24     AUS
# 25     AUS
# 26     AUS
# 27     AUS
# 28     AUS
# 29     AUS
#       ...
# 693    COL
# 694    COL
# 695    COL
# 696    LVA
# 697    LVA
# 698    LVA
# 699    LVA
# 700    LVA
# 701    LVA
# 702    LVA
# 703    LVA
# 704    LVA
# 705    LVA
# 706    LVA
# 707    LVA
# 708    LVA
# 709    LVA
# 710    LVA
# 711    LTU
# 712    LTU
# 713    LTU
# 714    LTU
# 715    LTU
# 716    LTU
# 717    LTU
# 718    LTU
# 719    LTU
# 720    LTU
# 721    LTU
# 722    LTU
# Name: location, Length: 723, dtype: object

# %%
df = df[df['location'] == 'USA']

# %%
df.time.unique()
# Out:
# array([1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
df = df[['value','time']]

# %%
df.columns
# Out:
# Index(['value', 'time'], dtype='object')

# %%
df
# Out:
#         value  time
# 522  70.74065  1987
# 523  71.64634  1988
# 524  72.49520  1989
# 525  72.19167  1990
# 526  70.96761  1991
# 527  70.80585  1992
# 528  71.20782  1993
# 529  72.00175  1994
# 530  72.53490  1995
# 531  72.85875  1996
# 532  73.50204  1997
# 533  73.84345  1998
# 534  73.94605  1999
# 535  74.09456  2000
# 536  73.13562  2001
# 537  71.92931  2002
# 538  71.22334  2003
# 539  71.22248  2004
# 540  71.53017  2005
# 541  71.99708  2006
# 542  71.78132  2007
# 543  70.88825  2008
# 544  67.62595  2009
# 545  66.68977  2010
# 546  66.64754  2011
# 547  67.13661  2012
# 548  67.35994  2013
# 549  68.14875  2014
# 550  68.70962  2015
# 551  69.35136  2016

# %%
suicide_stats_df = pd.read_csv('../02_data/who_suicide_statistics.csv')

# %%
suicide_stats_df = suicide_stats_df[suicide_stats_df['country']=='United States of America']

# %%
len(df)
# Out:
# 30

# %%
df
# Out:
#         value  time  time
# 522  70.74065  1987  1987
# 523  71.64634  1988  1988
# 524  72.49520  1989  1989
# 525  72.19167  1990  1990
# 526  70.96761  1991  1991
# 527  70.80585  1992  1992
# 528  71.20782  1993  1993
# 529  72.00175  1994  1994
# 530  72.53490  1995  1995
# 531  72.85875  1996  1996
# 532  73.50204  1997  1997
# 533  73.84345  1998  1998
# 534  73.94605  1999  1999
# 535  74.09456  2000  2000
# 536  73.13562  2001  2001
# 537  71.92931  2002  2002
# 538  71.22334  2003  2003
# 539  71.22248  2004  2004
# 540  71.53017  2005  2005
# 541  71.99708  2006  2006
# 542  71.78132  2007  2007
# 543  70.88825  2008  2008
# 544  67.62595  2009  2009
# 545  66.68977  2010  2010
# 546  66.64754  2011  2011
# 547  67.13661  2012  2012
# 548  67.35994  2013  2013
# 549  68.14875  2014  2014
# 550  68.70962  2015  2015
# 551  69.35136  2016  2016

# %%
suicide_stats_df
# Out:
#                         country  year     sex          age  suicides_no  \
# 41916  United States of America  1979  female  15-24 years       1001.0
# 41917  United States of America  1979  female  25-34 years       1352.0
# 41918  United States of America  1979  female  35-54 years       2458.0
# 41919  United States of America  1979  female   5-14 years         48.0
# 41920  United States of America  1979  female  55-74 years       1705.0
# 41921  United States of America  1979  female    75+ years        384.0
# 41922  United States of America  1979    male  15-24 years       4245.0
# 41923  United States of America  1979    male  25-34 years       4505.0
# 41924  United States of America  1979    male  35-54 years       5207.0
# 41925  United States of America  1979    male   5-14 years        104.0
# 41926  United States of America  1979    male  55-74 years       4593.0
# 41927  United States of America  1979    male    75+ years       1587.0
# ...
